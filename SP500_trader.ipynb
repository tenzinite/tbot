# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/list_of_S%26P_500_companies'
data = pd = pd.read_html(url)

# %%
df = data[1]
data[1].head()
#run above cells
# Out:
#                 Date  Added                       Removed  \
#                 Date Ticker              Security  Ticker
# 0  December 18, 2023   UBER                  Uber     SEE
# 1  December 18, 2023    JBL                 Jabil     ALK
# 2  December 18, 2023   BLDR  Builders FirstSource    SEDG
# 3   October 18, 2023   HUBB               Hubbell     OGN
# 4   October 18, 2023   LULU   Lululemon Athletica    ATVI
#
#                                                                    Reason
#               Security                                             Reason
# 0           Sealed Air                   Market capitalization change.[4]
# 1     Alaska Air Group                   Market capitalization change.[4]
# 2            SolarEdge                   Market capitalization change.[4]
# 3        Organon & Co.                   Market capitalization change.[5]
# 4  Activision Blizzard  S&P 500 and S&P 100 constituent Microsoft acqu...

# %%
df = df.sort_index(ascending=False)

# %%
newDf = df[[("Date", "Date"), ("Added", "Ticker"), ("Removed", "Ticker")]]
newDf.columns = newDf.columns.get_level_values(0)

# %%
newDf.head()
# Out:
#                   Date Added Removed
# 337      June 17, 1997   CCI     USL
# 336  December 11, 1998  CPWR     SUN
# 335  December 11, 1998   CCL     GRN
# 334  December 11, 1998   FSR     LDW
# 333       June 9, 1999   WLP     HPH

# %%
#all tickers
list(set(newDf["Added"].dropna()).union(set(newDf["Removed"].dropna())))
# Out:
# ['URI',
#  'LNC',
#  'FRT',
#  'AMCR',
#  'DLTR',
#  'VNO',
#  'KDP',
#  'CBOE',
#  'ABNB',
#  'NOW',
#  'TEL',
#  'RSH',
#  'AXON',
#  'NAVI',
#  'ATVI',
#  'REGN',
#  'DV',
#  'FRC',
#  'AVB',
#  'TDC',
#  'AME',
#  'PBI',
#  'SEDG',
#  'NOVL',
#  'MKTX',
#  'PDCO',
#  'NOV',
#  'NVR',
#  'BJS',
#  'TMC',
#  'DNR',
#  'WIN',
#  'TRMB',
#  'AMZN',
#  'JEF',
#  'LW',
#  'JOY',
#  'MPWR',
#  'PYPL',
#  'UHS',
#  'GRA',
#  'WFM',
#  'APC',
#  'TSLA',
#  'GM',
#  'SVU',
#  'ZBRA',
#  'NBL',
#  'CPT',
#  'TGNA',
#  'BXLT',
#  'HPE',
#  'SE',
#  'SEE',
#  'IGT',
#  'ADT',
#  'AVGO',
#  'MPC',
#  'ABBV',
#  'BC',
#  'ALLE',
#  'SUN',
#  'CZR',
#  'LSI',
#  'SLE',
#  'LDOS',
#  'AAL',
#  'HOT',
#  'ACAS',
#  'GT',
#  'TEG',
#  'FSR',
#  'AYE',
#  'CFN',
#  'DNB',
#  'ABS',
#  'BR',
#  'TER',
#  'HSIC',
#  'BHF',
#  'LEG',
#  'UBER',
#  'PCG',
#  'ITT',
#  'XTO',
#  'NWL',
#  'QEP',
#  'BG',
#  'VNT',
#  'DO',
#  'MGM',
#  'ROST',
#  'NDSN',
#  'TYL',
#  'CSC',
#  'X',
#  'ODFL',
#  'APOL',
#  'WFR',
#  'EP',
#  'EW',
#  'SWY',
#  'FNM',
#  'CELG',
#  'FICO',
#  'SNI',
#  'ROL',
#  'RJF',
#  'FSLR',
#  'MAT',
#  'QRVO',
#  'EVHC',
#  'KMX',
#  'KSS',
#  'AMD',
#  'T',
#  'YHOO',
#  'VRTX',
#  'GPN',
#  'NYT',
#  'FBHS',
#  'AV',
#  'BMC',
#  'COG',
#  'PVH',
#  'RTN',
#  'DISCK',
#  'NBR',
#  'MAA',
#  'SBUX',
#  'LIFE',
#  'HLT',
#  'CTVA',
#  'GEHC',
#  'NVLS',
#  'ODP',
#  'MNK',
#  'CRL',
#  'DYN',
#  'MOLX',
#  'DXC',
#  'FRX',
#  'COO',
#  'JOYG',
#  'MLM',
#  'BS',
#  'CE',
#  'PODD',
#  'AET',
#  'LRCX',
#  'ALB',
#  'PNR',
#  'ATO',
#  'KRFT',
#  'MEE',
#  'AA',
#  'AAP',
#  'BMS',
#  'FDO',
#  'CA',
#  'SLM',
#  'WRB',
#  'CVG',
#  'XEC',
#  'THC',
#  'PTC',
#  'HP',
#  'SBNY',
#  'PCP',
#  'SIG',
#  'TSG',
#  'XRX',
#  'MWW',
#  'CCL',
#  'NKTR',
#  'RAI',
#  'PGN',
#  'RIG',
#  'MBI',
#  'EQIX',
#  'LM',
#  'RE',
#  'FFIV',
#  'EMC',
#  'CTX',
#  'SLG',
#  'AGN',
#  'FAST',
#  'BTU',
#  'CMG',
#  'AYI',
#  'MRNA',
#  'BEAM',
#  'DWDP',
#  'EVRG',
#  'BX',
#  'HNZ',
#  'ALTR',
#  'ALK',
#  'TDY',
#  'UAL',
#  'TE',
#  'ANF',
#  'LVS',
#  'VIAB',
#  'DXCM',
#  'RX',
#  'TWC',
#  'AJG',
#  'CFG',
#  'WB',
#  'INTU',
#  'RAD',
#  'O',
#  'SMS',
#  'BRCM',
#  'OGN',
#  'CARR',
#  'MAC',
#  'FLIR',
#  'TECH',
#  'CLF',
#  'KSE',
#  'ACE',
#  'PSX',
#  'TMUS',
#  'BBBY',
#  'VAR',
#  'LYB',
#  'DAL',
#  'INCY',
#  'MOH',
#  'SNDK',
#  'QTRN',
#  'FL',
#  'HOG',
#  'CMCSK',
#  'ESRX',
#  'BCR',
#  'ETFC',
#  'GMCR',
#  'POM',
#  'IDXX',
#  'TTWO',
#  'HBI',
#  'HPH',
#  'ALGN',
#  'FTV',
#  'RRC',
#  'CCK',
#  'GHC',
#  'JNS',
#  'PRGO',
#  'JEC',
#  'WYN',
#  'DTV',
#  'FRE',
#  'ZTS',
#  'CDNS',
#  'GAS',
#  'IEX',
#  'ACN',
#  'TYC',
#  'TIE',
#  'UDR',
#  'KMI',
#  'TWX',
#  'NWSA',
#  'GENZ',
#  'STX',
#  'TLAB',
#  'EQT',
#  'TRGP',
#  'Q',
#  'JWN',
#  'GOOGL',
#  'SII',
#  'TFX',
#  'MUR',
#  'VICI',
#  'POOL',
#  'JBHT',
#  'STZ',
#  'HRL',
#  'CPRI',
#  'SGP',
#  'CIEN',
#  'IPGP',
#  'XYL',
#  'VRSK',
#  'BWA',
#  'REG',
#  'COV',
#  'COTY',
#  'MTD',
#  'MHK',
#  'TSCO',
#  'PENN',
#  'EK',
#  'CNX',
#  'JKHY',
#  'CRM',
#  'MON',
#  'FLS',
#  'FLR',
#  'ANET',
#  'MOS',
#  'MXIM',
#  'KFT',
#  'GRMN',
#  'FANG',
#  'CDW',
#  'GNRC',
#  'SWN',
#  'FDC',
#  'AIV',
#  'RRD',
#  'ACGL',
#  'SCG',
#  'SRCL',
#  'PETM',
#  'SIAL',
#  'HOLX',
#  'STLD',
#  'ABK',
#  'MNST',
#  'INVH',
#  'PTV',
#  'ARE',
#  'DJ',
#  'OMX',
#  'S',
#  'CDAY',
#  'BIO',
#  'RMD',
#  'JBL',
#  'CVH',
#  'MIL',
#  'NYX',
#  'NLSN',
#  'ENPH',
#  'FOSL',
#  'HRB',
#  'GGP',
#  'BRO',
#  'NE',
#  'LLTC',
#  'GPS',
#  'KEYS',
#  'TRB',
#  'VTR',
#  'WST',
#  'RHT',
#  'NCR',
#  'GR',
#  'JCP',
#  'CNC',
#  'SBAC',
#  'DOW',
#  'OTIS',
#  'HCA',
#  'FTR',
#  'UNM',
#  'DF',
#  'STI',
#  'INFO',
#  'PCS',
#  'FOX',
#  'STJ',
#  'STE',
#  'EXPE',
#  'WU',
#  'TDG',
#  'UAA',
#  'FII',
#  'ARG',
#  'PKG',
#  'PBCT',
#  'SAI',
#  'CTLT',
#  'ENDP',
#  'WCG',
#  'DG',
#  'WPX',
#  'URBN',
#  'AN',
#  'CHD',
#  'ESS',
#  'LNT',
#  'KVUE',
#  'CERN',
#  'DLR',
#  'BIG',
#  'NFLX',
#  'LVLT',
#  'ILMN',
#  'HFC',
#  'AMG',
#  'MSCI',
#  'ON',
#  'KHC',
#  'VLTO',
#  'ATI',
#  'XL',
#  'NSM',
#  'SHLD',
#  'ICE',
#  'NCLH',
#  'R',
#  'LLL',
#  'FHN',
#  'CEPH',
#  'BLK',
#  'CXO',
#  'KSU',
#  'MTCH',
#  'AKS',
#  'IR',
#  'FTNT',
#  'ETSY',
#  'M',
#  'FTI',
#  'MHS',
#  'LYV',
#  'CAM',
#  'CTXS',
#  'DISH',
#  'LUK',
#  'NXPI',
#  'RDC',
#  'SPLS',
#  'FMC',
#  'STR',
#  'OI',
#  'ALXN',
#  'JNPR',
#  'MI',
#  'UA',
#  'EXR',
#  'SIVB',
#  'EPAM',
#  'ARNC',
#  'WLP',
#  'HUBB',
#  'TIF',
#  'CSGP',
#  'CPRT',
#  'GLK',
#  'KG',
#  'DFS',
#  'TRIP',
#  'PLL',
#  'LULU',
#  'PAYC',
#  'RCL',
#  'MJN',
#  'USL',
#  'PCLN',
#  'LDW',
#  'DLPH',
#  'DPS',
#  'CPWR',
#  'LO',
#  'CHTR',
#  'IT',
#  'MBC',
#  'LKQ',
#  'CBE',
#  'DPZ',
#  'SLR',
#  'NWS',
#  'TSO',
#  'KORS',
#  'WLTW',
#  'GME',
#  'ANR',
#  'CEG',
#  'PCL',
#  'CFC',
#  'MFE',
#  'TSS',
#  'CSRA',
#  'HII',
#  'SNPS',
#  'GRN',
#  'HRS',
#  'SYF',
#  'ULTA',
#  'HCBK',
#  'TWTR',
#  'CHK',
#  'JNY',
#  'CCI',
#  'JDSU',
#  'PANW',
#  'FLT',
#  'NFX',
#  'AVP',
#  'ADS',
#  'HSP',
#  'HAR',
#  'COL',
#  'CB',
#  'LEH',
#  'GNW',
#  'DELL',
#  'ESV',
#  'CCE',
#  'LUMN',
#  'WAB',
#  'FB',
#  'ANSS',
#  'SWKS',
#  'DRE',
#  'CVC',
#  'AWK',
#  'ANDV',
#  'DD',
#  'BLDR',
#  'AOS',
#  'KBH',
#  'ABMD',
#  'LXK',
#  'FDS',
#  'CPGX',
#  'XLNX',
#  'HWM',
#  'V',
#  'MMI',
#  'SBL']

# %%
rows = {}
for i in range(len(newDf)):
    date = newDf["Date"][i]
    if date in rows:
        continue
    temp = newDf[ newDf["Date"] == date ]
    temp.reset_index(inplace=True)
    addedList = []
    removedList = []
    for j in range(len(temp)):
        if type(temp["Added"][j]) == str: #checking for nan values
            addedList.append(temp["Added"][j])
        if type(temp["Removed"][j]) == str: #checking for nan values
            removedList.append(temp["Removed"][j])
        rows[date] = {"added": addedList, "removed": removedList}

# %%
final_df = pd.DataFrame(rows).T
final_df.index = pd.to_datetime(final_df.index)
final_df = final_df.sort_index(ascending=True)
final_df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 final_df = pd.DataFrame(rows).T
#       2 final_df.index = pd.to_datetime(final_df.index)
#       3 final_df = final_df.sort_index(ascending=True)
#
# AttributeError: 'list' object has no attribute 'DataFrame'

# %%
final_df.head()

# %%
def transform(x):
    st = ""
    for i in x:
        st += i + " "
    return st

# %%
final_df["added"] = final_df["added"].apply(transform)
final_df["removed"] = final_df["removed"].apply(transform)

# %%
final_df

# %%
final_df.to_csv("SPYUpdates.csv", index=False)
